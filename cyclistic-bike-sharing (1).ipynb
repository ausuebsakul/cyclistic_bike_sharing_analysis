# %% [markdown]
# **Case Study 1 Case Study: How Does a Bike-Share Navigate Speedy Success?**
#
#
# <img src="attachment:761035f0-abe5-4adc-a430-a96085f9d419.png" width="200px" height="px">
#
# Introduction Welcome to the Cyclistic bike-share analysis case study! In this case study, you will perform many real-world tasks of a junior data analyst. You will work for a fictional company, Cyclistic, and meet different characters and team members. In order to answer the key business questions, you will follow the steps of the data analysis process: ask, prepare, process, analyze, share, and act. Along the way, the Case Study Roadmap tables — including guiding questions and key tasks — will help you stay on the right path. By the end of this lesson, you will have a portfolio-ready case study. Download the packet and reference the details of this case study anytime. Then, when you begin your job hunt, your case study will be a tangible way to demonstrate your knowledge and skills to potential employers.
#
# **Scenario**
#
# You are a junior data analyst working in the marketing analyst team at Cyclistic, a bike-share company in Chicago. The director of marketing believes the company’s future success depends on maximizing the number of annual memberships. Therefore, your team wants to understand how casual riders and annual members use Cyclistic bikes differently. From these insights, your team will design a new marketing strategy to convert casual riders into annual members. But first, Cyclistic executives must approve your recommendations, so they must be backed up with compelling data insights and professional data visualizations.

# %% [markdown]
# **Phase 1 : Ask**
#
# Key tasks
#
# 1. Identify the business task
#
#     - Identify the differences and similarities between the casul and member bike sharing users.
#     - Come up with a marketing strategy to convert the casual user to member user.
#
#
# 2. Consider key stakeholders :
#
#     - Lily Moreno: The director of marketing and my manager.
#     - Cyclistic executive team : The notoriously detail-oriented executive team will decide whether to approve the recommended marketing program.

# %% [markdown]
# **Phase 2: Prepare**
#
#
#
#     - Download the data of 2019 throughout Q1-Q4, store on my local computer and upload them to the Bigquery
#
#    ![image.png](attachment:b48392a3-fb2f-4490-8dbc-60f1b7ac5bdc.png)
#
#
#
#
#
#
#
#     - The data is well organized, eventhough the Q2 data has a different column names.
#
#    ![image.png](attachment:548270d5-3bd4-45ba-9e50-6b6403e97a97.png) ![image.png](attachment:ac45fb75-c377-49fb-a58e-c92e11320f83.png)
#
#
#
#     - Save a new table with the correct column names
#
#    ![image.png](attachment:1b51bcd0-d66d-4419-857a-32e96f256f75.png)
#
#    ![image.png](attachment:25cc7351-c95d-4314-bc5d-582034c278a2.png)
#
#      - Combine the data into a single table
#
#    ![image.png](attachment:042446f7-f2fb-4386-b4b6-722b18ce771c.png)

# %% [markdown]
# **Phase 3 : Prepare**
#
#     - Delete the duplciate
#
# ![image.png](attachment:19309942-defe-40fe-868b-617bccaba252.png)
#
#     - Finding any alien usertype
#
# ![image.png](attachment:619e20f4-94c5-4e40-b525-0303abddc483.png)
#
#     - Checking if there are any non-2019 ride. Turns out there are some rides begin in 2019 but end in 2020. This should not effect our analysis.
#
# ![image.png](attachment:e9fd7a76-b9ab-4102-8b2d-91280c50af8f.png)<img src="attachment:bae69777-cc69-4020-9a84-e19b2aacb090.png" width="300px" height="300px">
#
#     - Finding the unit of tripduration, they are not indicated. Turns out the trip duration is in second.
#
# ![image.png](attachment:9c2024ad-9957-4f25-a054-e63b22171191.png)<img src="attachment:f1e80864-1ef0-4fbc-a2d1-950b3282cf9c.png" width="250px" height="250px">
#
#     - Overview the birthyear range. There are some unreasonable birthyear, I am going to delete those who are older than 120 years old from the data.
#
# ![image.png](attachment:f562bf13-d1ce-4b8b-92c2-11c653d82f08.png)![image.png](attachment:5eebb45d-4c7f-4f85-a659-6f4a9b988057.png)
#
#
# ![image.png](attachment:70c00b17-d25d-4adb-a9c1-840a0e9bdf4c.png)![image.png](attachment:5189462f-6240-460b-a8ac-d530fb53cd32.png)

# %% [markdown]
# **Phase 4 : Process**
#
#     - Looking for some insight of the data
#
# ![image.png](attachment:cece24be-28bb-4798-a612-d7e875cd2842.png)
#
# ![image.png](attachment:ffdbbca6-1468-48b9-9edf-b283fec4b88e.png)
#
# ![image.png](attachment:d7dc6638-f057-4536-8596-a950a3b45679.png)
#
# ![image.png](attachment:19424b0b-a121-4683-bf95-6b338e7ed2e0.png)
#
#     - Specified age group to find some insight.
#
#
# ![image.png](attachment:732b5f45-ebc3-430c-a2f0-7c7cf9c672e0.png)
#
# ![image.png](attachment:3b54c073-9c46-431a-9f3e-fd71ae4d44b0.png)
#
#     - Convert the start time into weekday
#
#
# ![image.png](attachment:391b02e9-af7a-47d1-bd85-896affba667f.png)
#
# ![image.png](attachment:7b3f4703-865f-49a9-8e2f-3dcd4a403cdc.png)

# %% [markdown]
# Phase 4 : Analyze
#
# Programs used in this analysis
#
# 1. Google BigQuery
# 2. Tableau
#
# Average trip duration among the non-subscriber is 3.3 times higher than subscriber.
#
# ![average_trip_duration_of_users.png](attachment:84750ab5-71c5-4f5d-861a-f8ffa5c30f58.png)
#
# Most of the customers are in the age of 25-44.
#
# ![age_profile_of_users.png](attachment:44c11290-2f0f-4c3e-bce9-936de7374c72.png)
#
#  Subscriber uses bike sharing in the weekday, whereas non-subscriber's usage is in the weekend.
#
# ![number_of_trips_in_each_day_of_week.png](attachment:b625b3d5-386b-42c4-aa9f-dd99efe5a9f8.png)
#
#    It seems like the non-subscriber uses the bike in the leisure time since they have a longer trip duration and tend to use in the weekend.
#    I need to confirm this by using the location of beginning station and ending station to find the trip pattern.
#
#    Since i did not prepare the latitude and longitude of each station beforehand, I need to download another table from [Link](https://data.cityofchicago.org/Transportation/Divvy-Bicycle-Stations/bbyy-e7gq/data) And join the new table to my data
#
#    ![image.png](attachment:edf5b158-46bc-48b0-a85e-1252ab9be945.png)
#
#    Find the top 150 favourite route among subscriber and non-subscriber
#
#    ![image.png](attachment:331f9baa-cd59-439c-979d-484364177a8d.png)
#
#    ![image.png](attachment:28bc3bbf-4f1b-4965-8550-3a210b381cd5.png)
#
#
# Plotting the route on Tableau
#
#
# ![Non-Subscriber Favourite Route_cropped.png](attachment:9a275c0e-c39d-4ab9-acfd-e69c22e80e81.png) ![Subscriber Favourite Route_cropped.png](attachment:44a915d6-4317-45d8-8331-592a4cf6d759.png)
#
# After plotting the route on Tableau, it seems that my assumption is correct.
#
# The non-subscriber (Left) tend to use the bike sharing on their leisure time, their ruote are park and sight seeing area focused.
#
# The subscriber (Right) using time is on the weekday, and their route are mainly focus in the city where the office located.

# %% [markdown]
# **Phase 5 : Share**
#
# The difference between non-subscriber and subscriber are:
# * Non-subscriber has a higher using duration
# * Non-subscriber tend to use the bike sharing on the weekend
# * Non-subscriber's favourite routes are mainly focus on the park and coastal area
#
# The similarity between non-subscriber and subscriber are:
# * Age profile of both type are distributed in the same manner.
#
# **Conclusion:** The non-subscribers tend to use the bike sharing on their leisure time for sightseeing, whereas the subscribers use the bike sharing as a daily transportation to their work place.

# %% [markdown]
# **Phase 6 : Act**
